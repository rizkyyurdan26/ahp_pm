# %%
import pandas as pd

# %% [markdown]
# ### Split data lahan

# %%
df = pd.read_excel('./dataset/data_lahan_full.xlsx')
df.head()
# Out:
#   nama_lahan  suhu_mean  curah_hujan  kelembapan_udara  penyinaran  \
# 0     Bakung     26.202       1133.2            83.806       7.749
# 1   Binangun     25.422       1133.2            83.806       7.749
# 2       Doko     24.817       1741.1            84.174       7.208
# 3  Gandusari     24.732       1741.1            84.174       7.208
# 4      Garum     25.408       1741.1            84.174       7.208
#
#    kelembapan_tanah                                  jenis_tanah  ketinggian  \
# 0             0.272         kompleks litosol, mediteran, renzina         160
# 1             0.272                                    mediteran         243
# 2             0.198  asosiasi latosol cokelat dan regosol kelabu         349
# 3             0.198                 kompleks regosol dan litosol         348
# 4             0.198                                      regosol         276
#
#    kemiringan drainase    ph     tekstur_tanah
# 0        45.0   lancar  6.70           berbatu
# ...

# %%
df.columns
# Out:
# Index(['nama_lahan', 'suhu_mean', 'curah_hujan', 'kelembapan_udara',
#        'penyinaran', 'kelembapan_tanah', 'jenis_tanah', 'ketinggian',
#        'kemiringan', 'drainase', 'ph', 'tekstur_tanah'],
#       dtype='object')

# %%
iklim = df[['nama_lahan', 'suhu_mean', 'curah_hujan', 'kelembapan_udara', 'penyinaran']]

iklim.to_excel('./dataset/split_data/lahan_iklim.xlsx', index=False)

# %%
topografi = df[['nama_lahan', 'ketinggian', 'kemiringan', 'drainase']]

topografi.to_excel('./dataset/split_data/lahan_topografi.xlsx', index=False)

# %%
tanah = df[['nama_lahan', 'ph', 'kelembapan_tanah', 'jenis_tanah','tekstur_tanah' ]]

tanah.to_excel('./dataset/split_data/lahan_tanah.xlsx', index=False)

# %% [markdown]
# ### split data varietas

# %%
df1 = pd.read_excel('./dataset/data_varietas.xlsx')
df1
# Out:
#   jenis_varietas  suhu_max  suhu_min  curah_hujan_max  curah_hujan_min  \
# 0             MM        33        18             1200              500
# 1             MR        35        20             1200              500
# 2             MK        35        22             1200              500
# 3             MW        35        20             1200              500
# 4             MT        30        18             1200              500
#
#    kelembapan_udara_max  kelembapan_udara_min  \
# 0                   100                    60
# 1                   100                    50
# 2                   100                    50
# 3                   100                    40
# 4                   100                    60
#
#                                    jenis_tanah  kemiringan_min  \
# 0  asosiasi latosol cokelat dan regosol kelabu               0
# 1                 kompleks regosol dan litosol               0
# 2                 kompleks regosol dan litosol               0
# ...

# %%
df1.columns
# Out:
# Index(['jenis_varietas', 'suhu_max', 'suhu_min', 'curah_hujan_max',
#        'curah_hujan_min', 'kelembapan_udara_max', 'kelembapan_udara_min',
#        'jenis_tanah', 'kemiringan_min', 'kemiringan_max', 'drainase',
#        'tekstur_tanah', 'kelembapan_tanah_min', 'kelembapan_tanah_max',
#        'ketinggian_min', 'ketinggian_max', 'penyinaran_min', 'penyinaran_max',
#        'ph_min', 'ph_max'],
#       dtype='object')

# %%
iklim = df1[['jenis_varietas', 'suhu_min', 'suhu_max', 'curah_hujan_min', 'curah_hujan_max', 'kelembapan_udara_min', 'kelembapan_udara_max', 'penyinaran_min', 'penyinaran_max']]

iklim.to_excel('./dataset/split_data/varietas_iklim.xlsx', index=False)

# %%
topografi = df1[['jenis_varietas','ketinggian_min', 'ketinggian_max', 'kemiringan_min', 'kemiringan_max', 'drainase']]

topografi.to_excel('./dataset/split_data/varietas_topografi.xlsx', index=False)

# %%
tanah = df1[['jenis_varietas','ph_min', 'ph_max', 'kelembapan_tanah_min', 'kelembapan_tanah_max', 'jenis_tanah', 'tekstur_tanah']]


tanah.to_excel('./dataset/split_data/varietas_tanah.xlsx', index=False)
